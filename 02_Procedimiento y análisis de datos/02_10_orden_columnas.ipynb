# %%
import pandas as pd

# %%
df = pd.read_csv('02_10_emisiones.csv', delimiter=";")

# %%
print(df.head(10))
# Out:
#    Motor  Cilindros  Consumo Ciudad  Consumo Autopista  CO2
# 0    2.1          4            13.7                9.1  290
# 1    2.6          4            12.7                8.6  327
# 2    2.0          4            13.7                9.4  382
# 3    4.3          4            14.3                9.0  347
# 4    3.6          4            14.6               10.4  377
# 5    4.0          4             9.5                8.5  327
# 6    4.2          6            10.2                9.9  382
# 7    4.5          4            13.7               10.4  347
# 8    4.4          6            18.4                7.1  377
# 9    2.7          6            13.7                9.3  294

# %% [markdown]
# - Desafío: Cambiar el orden de las columnas, intercambiando la columna Consumo Ciudad por la columna Consumo Autopista

# %%
df = df[['Motor', 'Cilindros', 'Consumo Autopista', 'Consumo Ciudad', 'CO2']]

# %%
print(df.head(10))
# Out:
#    Motor  Cilindros  Consumo Autopista  Consumo Ciudad  CO2
# 0    2.1          4                9.1            13.7  290
# 1    2.6          4                8.6            12.7  327
# 2    2.0          4                9.4            13.7  382
# 3    4.3          4                9.0            14.3  347
# 4    3.6          4               10.4            14.6  377
# 5    4.0          4                8.5             9.5  327
# 6    4.2          6                9.9            10.2  382
# 7    4.5          4               10.4            13.7  347
# 8    4.4          6                7.1            18.4  377
# 9    2.7          6                9.3            13.7  294
