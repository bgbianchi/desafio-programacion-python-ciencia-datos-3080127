# %%
import pandas as pd

# %%
df = pd.read_csv('02_05_temperaturas.csv', delimiter=";")

# %%
print(df)
# Out:
#      Año  Temperatura
# 0   1960         71.4
# 1   1961         71.9
# 2   1962         71.9
# 3   1963         72.3
# 4   1964         71.7
# ..   ...          ...
# 57  2017         74.6
# 58  2018         73.5
# 59  2019         72.7
# 60  2020         74.6
# 61  2021         73.5
#
# [62 rows x 2 columns]

# %%
nueva_temperatura = pd.DataFrame.from_dict([{'Año': '2022', 'Temperatura': '74.3'}])

# %% [markdown]
# - Desafío: Agregar una nueva fila a nuestro dataframe

# %%
df_nuevo = pd.concat([df, nueva_temperatura], ignore_index=True)
print(df_nuevo)
# Out:
#      Año Temperatura
# 0   1960        71.4
# 1   1961        71.9
# 2   1962        71.9
# 3   1963        72.3
# 4   1964        71.7
# ..   ...         ...
# 58  2018        73.5
# 59  2019        72.7
# 60  2020        74.6
# 61  2021        73.5
# 62  2022        74.3
#
# [63 rows x 2 columns]
