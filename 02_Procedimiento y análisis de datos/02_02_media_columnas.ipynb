# %%
import pandas as pd

# %%
df = pd.read_csv('02_02_empleados.csv', delimiter=";")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Edad         143 non-null    int64
#  1   Experiencia  143 non-null    int64
#  2   Salario      143 non-null    int64
# dtypes: int64(3)
# memory usage: 3.5 KB
# None

# %% [markdown]
# - Desafío: Obtener el promedio de cada una de las columnas de nuestro dataframe

# %%
df.mean(axis=0, numeric_only=True)
# Out:
# Edad             33.797203
# Experiencia       6.867133
# Salario        2778.657343
# dtype: float64
