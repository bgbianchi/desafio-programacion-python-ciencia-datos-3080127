# %%
import pandas as pd

# %%
df = pd.read_csv('02_03_temperaturas.csv', delimiter=";")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Año          62 non-null     int64
#  1   temperatura  62 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB
# None

# %% [markdown]
# - Media: Promedio del rango de valores de los datos.
# - Varianza: Qué tan lejos se dispersan los valores de la media.
# - Desviación estándar: raíz cuadrada de la Varianza.
# - Rango: Diferencia entre el máximo y el mínimo

# %% [markdown]
# - Desafío: Encontrar el mínimo, el máximo, la varianza y la desviación estándar del dataframe que contiene información de temperaturas

# %%
print(df.isnull().sum())
# Out:
# Año            0
# temperatura    0
# dtype: int64

# %%
df.min()
# Out:
# Año            1960.0
# temperatura      70.9
# dtype: float64

# %%
df.max()
# Out:
# Año            2021.0
# temperatura      75.3
# dtype: float64

# %%
df.mean()
# Out:
# Año            1990.500000
# temperatura      72.624194
# dtype: float64

# %%
df.var()
# Out:
# Año            325.50000
# temperatura      1.11793
# dtype: float64

# %%
df.std()
# Out:
# Año            18.041619
# temperatura     1.057322
# dtype: float64
