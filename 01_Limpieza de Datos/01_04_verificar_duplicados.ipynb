# %%
import pandas as pd

# %%
df = pd.read_csv('01_04_empleados.csv', delimiter=";")

# %%
print(df.shape)
# Out:
# (145, 8)

# %% [markdown]
# - Desafío: Averiguar si nuestro dataframe tiene filas duplicadas

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 140    False
# 141    False
# 142    False
# 143    False
# 144    False
# Length: 145, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df["Duplicated"] = df.duplicated()

# %%
df.query("Duplicated")
# Out:
#     Nombre       Sexo Estado_Civil  Edad  Experiencia  Salario Gerencia  \
# 10  Selena   Femenino    Casado(a)    24            6     2709       Sí
# 34   Lucio  Masculino   Soltero(a)    54           12     3317       No
#
#         Departamento  Duplicated
# 10      Contabilidad        True
# 34  Recursos Humanos        True

# %%
df.query("Nombre == 'Selena'")
# Out:
#     Nombre      Sexo Estado_Civil  Edad  Experiencia  Salario Gerencia  \
# 6   Selena  Femenino    Casado(a)    24            6     2709       Sí
# 10  Selena  Femenino    Casado(a)    24            6     2709       Sí
#
#     Departamento  Duplicated
# 6   Contabilidad       False
# 10  Contabilidad        True
